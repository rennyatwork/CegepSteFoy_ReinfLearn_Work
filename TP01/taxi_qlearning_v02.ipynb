# %% [markdown]
# <a href="https://colab.research.google.com/github/rennyatwork/CegepSteFoy_ReinfLearn_Work/blob/main/TP01/taxi_qlearning_v02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 9.9 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import random
from IPython.display import clear_output


def create_q_table(env):
  """Creates a Q-table with all values initialized to 0.

  Args:
    env: The Gymnasium environment.

  Returns:
    A NumPy array representing the Q-table.
  """
  return np.zeros([env.observation_space.n, env.action_space.n])

def plot_reward_evolution(rewards
                          , pXLabel = 'Episode'
                          , pYLabel = 'Reward'
                          , pTitle='Reward Evolution during Training'):
  """Plots the evolution of rewards over episodes.

  Args:
    rewards: A list of rewards obtained during training.
  """
  plt.clf() #clear cell
  plt.plot(rewards)
  plt.xlabel(pXLabel)
  plt.ylabel(pYLabel)
  plt.title(pTitle)

  # Calculate tick positions for 10 evenly spaced labels
  num_ticks = 10
  x_min = 0  # Assume x-axis starts at 0
  x_max = len(rewards) - 1  # Assume x-axis ends at the last data point
  tick_positions = np.linspace(x_min, x_max, num_ticks, dtype=int)

   # Set x-axis ticks and labels
  plt.xticks(tick_positions, tick_positions)  # Set both positions and labels


  plt.show()

def get_policy(q_table, state, epsilon):
  """Selects an action using the epsilon-greedy policy.

  Args:
    q_table: The Q-table containing learned values.
    state: The current state of the environment.
    epsilon: The exploration rate.

  Returns:
    The action selected by the policy.
  """
  if np.random.uniform(0, 1) < epsilon:
    action = env.action_space.sample()  # Explore action space
  else:
    action = np.argmax(q_table[state])  # Exploit learned values
  return action

def train_q_learning(env
                     , q_table
                     , alpha=0.1
                     , gamma=0.9
                     , epsilon=1.0
                     , episodes=100000
                     , pPrint=False
                     ):
  """Trains the Q-learning agent.

  Args:
    env: The Gymnasium environment.
    q_table: The Q-table to update.
    alpha: The learning rate.
    gamma: The discount factor.
    epsilon: The exploration rate.
    episodes: The number of training episodes.
  """

  rewards = []
  all_rewards_per_episode = [] # List to store rewards per episode
  epsilon_decay = 0.9999  # Example decay rate


  for i in range(1, episodes + 1):
    state = env.reset()[0]
    epochs, penalties, reward = 0, 0, 0
    done = False


    while not done:

      action = get_policy(q_table, state, epsilon)

      # Decay epsilon over time:
      epsilon *= epsilon_decay
      epsilon = max(epsilon, 0.1) # set the min epsilon

      next_state, reward, done, truncated, info = env.step(action)

      old_value = q_table[state, action]
      next_max = np.max(q_table[next_state])

      new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
      q_table[state, action] = new_value

      if reward == -10:
        penalties += 1

      state = next_state
      epochs += 1

      rewards.append(reward)




    if pPrint:
      print("****************************************************")
      print(f"Episode: {i}")
      print(f"Timesteps taken: {epochs}")
      print(f"Penalties incurred: {penalties}")


    all_rewards_per_episode.append(np.mean(rewards)) # Calculating avg. reward per episode

    ten_pct_print = int(episodes/10)

    if i % (ten_pct_print) == 0:
      #print(f"Episode: {i}")
      avg_reward_last_100 = np.mean(all_rewards_per_episode[-ten_pct_print:]) # Calculating avg. reward for the last 100 episodes
      print(f"Episode: {i}, Average reward (last {ten_pct_print} episodes): {avg_reward_last_100}, current epsilon: {epsilon}")


    #if i % 1000 == 0:
     # plot_reward_evolution(rewards)

  print("Training finished.\n")

def evaluate_agent(env, q_table, episodes=100, pPrint=False):
  """Evaluates the trained agent.

  Args:
    env: The Gymnasium environment.
    q_table: The trained Q-table.
    episodes: The number of evaluation episodes.

  Returns:
    The average reward over the evaluation episodes.
  """

  if pPrint:
      print('Evaluating agent...')

  arr_avg_rewards = []
  arr_total_rewards = []
  arr_total_steps = []
  arr_penalties = []

  total_rewards = 0
  for ep in range(episodes):
    state = env.reset()[0]
    done = False
    episode_reward = 0

    steps_so_far = 0
    penalties = 0


    while not done and (steps_so_far < 300 or penalties <20):
      action = np.argmax(q_table[state])
      state, reward, done, truncated, info = env.step(action)
      steps_so_far +=1

      episode_reward += reward

      if reward == -10:
        penalties += 1

      reward_per_step = episode_reward / steps_so_far


      if (pPrint and (steps_so_far % 50) ==0):
        print(f'steps_so_far: {steps_so_far}')
        print(f'Reward/step in episode [{ep}]: {reward_per_step}')

    total_rewards += episode_reward

    if pPrint:
      print(f"Episode [{ep}] [reward]: {episode_reward} - [reward/step]: {reward_per_step} - [penalties]: {penalties} - [total_steps]: {steps_so_far}")
      #print(f"Episode [{ep}] reward/step: {reward_per_step}")
      #print(f"Episode [{ep}] penalties: {penalties}")

    arr_total_steps.append(steps_so_far)
    arr_penalties.append(penalties)
    arr_avg_rewards.append(reward_per_step)
    arr_total_rewards.append(episode_reward)

  print(f"Results after {episodes} episodes:")
  print(f'len(arr_avg_rewards): {len(arr_avg_rewards)} ')
  print(f'len(arr_total_rewards): {len(arr_total_rewards)} ')
  print(f'len(arr_total_steps): {len(arr_total_steps)} ')
  print(f'len(arr_penalties): {len(arr_penalties)} ')


  plot_reward_evolution(arr_avg_rewards
                        , pYLabel='Average Reward'
                        , pTitle='Average Reward evolution')
  plot_reward_evolution(arr_total_rewards
                        , pYLabel='Total Rewards'
                        , pTitle='Total Rewards evolution')
  plot_reward_evolution(arr_total_steps
                        , pYLabel='Total Steps'
                        , pTitle='Total Steps evolution')
  plot_reward_evolution(arr_penalties
                        , pYLabel='Penalties'
                        , pTitle='Penalties evolution')

  return total_rewards / episodes

# %%
# Main execution
env = gym.make("Taxi-v3")
q_table = create_q_table(env)
train_q_learning(env, q_table
                 , epsilon=1.0
                 , episodes=15000)
average_reward = evaluate_agent(env
                                , q_table
                                , episodes=200
                                ,  pPrint=True)

print(f"Average reward: {average_reward}")
# Out:
# Episode: 1500, Average reward (last 1500 episodes): -1.4649832624975327, current epsilon: 0.1
# Episode: 3000, Average reward (last 1500 episodes): -1.1057448829369214, current epsilon: 0.1
# Episode: 4500, Average reward (last 1500 episodes): -0.9021608686042347, current epsilon: 0.1
# Episode: 6000, Average reward (last 1500 episodes): -0.754405308574846, current epsilon: 0.1
# Episode: 7500, Average reward (last 1500 episodes): -0.6403986349145492, current epsilon: 0.1
# Episode: 9000, Average reward (last 1500 episodes): -0.5519957100460335, current epsilon: 0.1
# Episode: 10500, Average reward (last 1500 episodes): -0.4816274928491606, current epsilon: 0.1
# Episode: 12000, Average reward (last 1500 episodes): -0.4242665455987166, current epsilon: 0.1
# Episode: 13500, Average reward (last 1500 episodes): -0.3763281631913586, current epsilon: 0.1
# Episode: 15000, Average reward (last 1500 episodes): -0.3358721101261684, current epsilon: 0.1
# Training finished.
#
# Evaluating agent...
# Episode [0] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [1] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [2] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [3] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [4] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [5] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [6] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [7] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [8] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [9] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [10] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [11] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [12] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [13] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [14] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [15] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [16] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [17] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [18] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [19] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [20] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [21] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [22] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [23] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [24] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [25] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [26] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [27] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [28] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [29] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [30] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [31] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [32] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [33] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [34] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [35] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [36] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [37] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [38] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [39] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [40] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [41] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [42] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [43] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [44] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [45] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [46] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [47] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [48] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [49] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [50] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [51] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [52] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [53] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [54] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [55] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [56] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [57] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [58] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [59] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [60] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [61] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [62] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [63] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [64] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [65] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [66] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [67] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [68] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [69] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [70] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [71] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [72] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [73] [reward]: 3 - [reward/step]: 0.16666666666666666 - [penalties]: 0 - [total_steps]: 18
# Episode [74] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [75] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [76] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [77] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [78] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [79] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [80] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [81] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [82] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [83] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [84] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [85] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [86] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [87] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [88] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [89] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [90] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [91] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [92] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [93] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [94] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [95] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [96] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [97] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [98] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [99] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [100] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [101] [reward]: 3 - [reward/step]: 0.16666666666666666 - [penalties]: 0 - [total_steps]: 18
# Episode [102] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [103] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [104] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [105] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [106] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [107] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [108] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [109] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [110] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [111] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [112] [reward]: 3 - [reward/step]: 0.16666666666666666 - [penalties]: 0 - [total_steps]: 18
# Episode [113] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [114] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [115] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [116] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [117] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [118] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [119] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [120] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [121] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [122] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [123] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [124] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [125] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [126] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [127] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [128] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [129] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [130] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [131] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [132] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [133] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [134] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [135] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [136] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [137] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [138] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [139] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [140] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [141] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [142] [reward]: 3 - [reward/step]: 0.16666666666666666 - [penalties]: 0 - [total_steps]: 18
# Episode [143] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [144] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [145] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [146] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [147] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [148] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [149] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [150] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [151] [reward]: 14 - [reward/step]: 2.0 - [penalties]: 0 - [total_steps]: 7
# Episode [152] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [153] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [154] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [155] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [156] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [157] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [158] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [159] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [160] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [161] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [162] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [163] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [164] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [165] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [166] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [167] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [168] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [169] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [170] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [171] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [172] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [173] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [174] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [175] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [176] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [177] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [178] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [179] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [180] [reward]: 10 - [reward/step]: 0.9090909090909091 - [penalties]: 0 - [total_steps]: 11
# Episode [181] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [182] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [183] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [184] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [185] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [186] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [187] [reward]: 13 - [reward/step]: 1.625 - [penalties]: 0 - [total_steps]: 8
# Episode [188] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [189] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [190] [reward]: 11 - [reward/step]: 1.1 - [penalties]: 0 - [total_steps]: 10
# Episode [191] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [192] [reward]: 8 - [reward/step]: 0.6153846153846154 - [penalties]: 0 - [total_steps]: 13
# Episode [193] [reward]: 7 - [reward/step]: 0.5 - [penalties]: 0 - [total_steps]: 14
# Episode [194] [reward]: 5 - [reward/step]: 0.3125 - [penalties]: 0 - [total_steps]: 16
# Episode [195] [reward]: 12 - [reward/step]: 1.3333333333333333 - [penalties]: 0 - [total_steps]: 9
# Episode [196] [reward]: 6 - [reward/step]: 0.4 - [penalties]: 0 - [total_steps]: 15
# Episode [197] [reward]: 4 - [reward/step]: 0.23529411764705882 - [penalties]: 0 - [total_steps]: 17
# Episode [198] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Episode [199] [reward]: 9 - [reward/step]: 0.75 - [penalties]: 0 - [total_steps]: 12
# Results after 200 episodes:
# len(arr_avg_rewards): 200
# len(arr_total_rewards): 200
# len(arr_total_steps): 200
# len(arr_penalties): 200
# Average reward: 7.905
